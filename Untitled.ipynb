# %%
2^1
# Out:
# 3

# %%
if 4>5:
    print(4)
elif 5>4:
    print(5)
# Out:
# 5

# %%
x=3
match x:
    case 1:
        print("c1")
    case 5:
        print("c5")
    case _:
        print("Nothing")
# Out:
# Nothing

# %%
for i in range(5):
    if i == 10:
        print("Found")
        break
else:
    print("Not found")
# Out:
# Not found
